# %%
using Colors, MNIST

# %%
images, labels = traindata()
img = Gray.(reshape(images[:, 1], 28, 28))
# Out:
# 28×28 Array{ColorTypes.Gray{Float64},2}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  ⋮                                       ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
# ...
